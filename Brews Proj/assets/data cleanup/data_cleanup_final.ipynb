# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
import csv
import json
import numpy as np
import pymongo

# %%
def create_json(fileLocation,column):
    json1_file = open(fileLocation)
    json1_str = json1_file.read()
    json1_data = json.loads(json1_str)
    json1_data

    json_df = pd.DataFrame(json1_data).transpose()
    # print(json_df)

    count = json_df[column].count()
    states_dict = {"name":"", "children":[], "size":count}
    objToAddList = []

    for index, row in json_df.iterrows():
        objToAdd = {
                "name": row[column],
                "children": None,
                "score":row['Avg Overall Score'],
                "size": row['Quantity']
            }
        objToAddList.append(objToAdd)
        print(row)

    states_dict["children"] = objToAddList
    states_dict["name"] = column


    return states_dict

# %%
jsonsToClean = ['styles.json','cities.json']
columnsToClean = ['State','City']

my_dict = create_json('states.json','State')
my_dict
# Out:
# ABV(%)               7.24889
# Appearance            3.9648
# Aroma                3.92184
# Avg Overall Score    4.00145
# Palate                3.9306
# Quantity                  21
# State                     CA
# Taste                4.01724
# Name: 0, dtype: object
# ABV(%)                6.8965
# Appearance           3.85219
# Aroma                3.78089
# Avg Overall Score    3.83109
# Palate                3.7726
# Quantity                  16
# State                     CO
# Taste                3.80263
# Name: 1, dtype: object
# ABV(%)                     8
# Appearance           4.23684
# Aroma                4.13938
# Avg Overall Score    4.23501
# Palate               4.26023
# Quantity                   1
# State                     CT
# Taste                4.29922
# Name: 2, dtype: object
# ABV(%)               6.55556
# Appearance           3.90149
# Aroma                3.80814
# Avg Overall Score    3.83173
# Palate               3.85163
# Quantity                   3
# State                     DC
# Taste                3.83136
# Name: 3, dtype: object
# ABV(%)               8.66667
# Appearance           3.88902
# Aroma                 3.9239
# Avg Overall Score    3.79801
# Palate               3.80656
# Quantity                   3
# State                     DE
# Taste                3.93259
# Name: 4, dtype: object
# ABV(%)                     5
# Appearance           3.29653
# Aroma                3.25725
# Avg Overall Score    3.46234
# Palate               3.39431
# Quantity                   2
# State                     HI
# Taste                3.39761
# Name: 5, dtype: object
# ABV(%)               9.32068
# Appearance           3.99274
# Aroma                4.04608
# Avg Overall Score    4.04006
# Palate               4.01616
# Quantity                   3
# State                     IL
# Taste                4.08482
# Name: 6, dtype: object
# ABV(%)                4.4703
# Appearance           3.39113
# Aroma                3.21973
# Avg Overall Score    3.37702
# Palate               3.23819
# Quantity                   2
# State                     LA
# Taste                3.25432
# Name: 7, dtype: object
# ABV(%)               6.70317
# Appearance           3.87646
# Aroma                3.74927
# Avg Overall Score    3.86042
# Palate               3.78574
# Quantity                  43
# State                     MA
# Taste                3.81908
# Name: 8, dtype: object
# ABV(%)                   8.3
# Appearance           4.08023
# Aroma                4.05706
# Avg Overall Score    3.96031
# Palate               3.96497
# Quantity                   1
# State                     MD
# Taste                4.05141
# Name: 9, dtype: object
# ABV(%)                  5.92
# Appearance            3.8838
# Aroma                3.73461
# Avg Overall Score    3.86864
# Palate               3.75497
# Quantity                  10
# State                     ME
# Taste                3.83052
# Name: 10, dtype: object
# ABV(%)               6.76515
# Appearance           3.94837
# Aroma                3.80599
# Avg Overall Score    3.94654
# Palate               3.92078
# Quantity                   5
# State                     NC
# Taste                3.87682
# Name: 11, dtype: object
# ABV(%)               6.15833
# Appearance            3.9532
# Aroma                3.83532
# Avg Overall Score    3.91757
# Palate               3.87343
# Quantity                   6
# State                     NH
# Taste                3.93218
# Name: 12, dtype: object
# ABV(%)               7.00978
# Appearance           4.00167
# Aroma                 3.9166
# Avg Overall Score    3.97711
# Palate               3.89611
# Quantity                  14
# State                     NY
# Taste                3.96178
# Name: 13, dtype: object
# ABV(%)                   6.5
# Appearance           3.96586
# Aroma                3.76104
# Avg Overall Score    3.82769
# Palate               3.76104
# Quantity                   1
# State                     OR
# Taste                3.80723
# Name: 14, dtype: object
# ABV(%)                 8.675
# Appearance           3.90081
# Aroma                3.89881
# Avg Overall Score    3.90848
# Palate               3.90126
# Quantity                   4
# State                     PA
# Taste                3.94922
# Name: 15, dtype: object
# ABV(%)                   5.1
# Appearance            3.6991
# Aroma                3.50752
# Avg Overall Score    3.61075
# Palate                3.5775
# Quantity                   5
# State                     RI
# Taste                3.57803
# Name: 16, dtype: object
# ABV(%)                   9.2
# Appearance           4.10062
# Aroma                4.02896
# Avg Overall Score    3.96719
# Palate               3.96333
# Quantity                   2
# State                     UT
# Taste                4.02333
# Name: 17, dtype: object
# ABV(%)                  5.65
# Appearance           3.65755
# Aroma                3.40145
# Avg Overall Score    3.58277
# Palate               3.68111
# Quantity                   2
# State                     VA
# Taste                3.52653
# Name: 18, dtype: object
# ABV(%)               5.13788
# Appearance           3.60674
# Aroma                3.48158
# Avg Overall Score    3.60796
# Palate               3.53528
# Quantity                   6
# State                     VT
# Taste                3.56333
# Name: 19, dtype: object
# ABV(%)               6.74739
# Appearance           3.52564
# Aroma                3.51038
# Avg Overall Score    3.59388
# Palate               3.47913
# Quantity                   2
# State                     WA
# Taste                3.50181
# Name: 20, dtype: object
# {'name': 'State',
#  'children': [{'name': ' CA',
#    'children': None,
#    'score': 4.0014478657,
#    'size': 21},
#   {'name': ' CO', 'children': None, 'score': 3.8310927094, 'size': 16},
#   {'name': ' CT', 'children': None, 'score': 4.2350097466, 'size': 1},
#   {'name': ' DC', 'children': None, 'score': 3.831725458, 'size': 3},
#   {'name': ' DE', 'children': None, 'score': 3.7980148986, 'size': 3},
#   {'name': ' HI', 'children': None, 'score': 3.462338258, 'size': 2},
#   {'name': ' IL', 'children': None, 'score': 4.0400613238, 'size': 3},
#   {'name': ' LA', 'children': None, 'score': 3.3770235491, 'size': 2},
#   {'name': ' MA', 'children': None, 'score': 3.8604235016, 'size': 43},
#   {'name': ' MD', 'children': None, 'score': 3.9603107345, 'size': 1},
#   {'name': ' ME', 'children': None, 'score': 3.8686357523, 'size': 10},
#   {'name': ' NC', 'children': None, 'score': 3.9465356343, 'size': 5},
#   {'name': ' NH', 'children': None, 'score': 3.9175735158, 'size': 6},
#   {'name': ' NY', 'children': None, 'score': 3.9771056708, 'size': 14},
#   {'name': ' OR', 'children': None, 'score': 3.8276907631, 'size': 1},
#   {'name': ' PA', 'children': None, 'score': 3.9084787828, 'size': 4},
#   {'name': ' RI', 'children': None, 'score': 3.6107521933, 'size': 5},
#   {'name': ' UT', 'children': None, 'score': 3.9671875, 'size': 2},
#   {'name': ' VA', 'children': None, 'score': 3.5827669743, 'size': 2},
#   {'name': ' VT', 'children': None, 'score': 3.6079642416, 'size': 6},
#   {'name': ' WA', 'children': None, 'score': 3.5938777928, 'size': 2}],
#  'size': 21}
